# %% [markdown]
# # Anomaly Detection in Operations - Comprehensive Example
#
# This notebook demonstrates the complete anomaly detection pipeline for operational data.
#
# ## ⚠️ DISCLAIMER
# **This is a research and educational tool. Do NOT use for automated decision-making without human review.**
